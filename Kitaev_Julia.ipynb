# %% [markdown]
# Julia code for Kitaev model.
# \section{Kitaev model without symmetry}

# %%
function index(N1, N2, c, r, atom)
    #Calculate the index of the atoms in the (r,c) unit cell
    c = (c + N1) % N1 
    r = (r + N2) % N2 
    #println("(",r,",",c,")")
    n = r * N1 + c 
    if atom == 'A'
        ind = 2 * n + 1
    elseif atom == 'B'
        ind = 2 * n + 1 + 1
    else
        return println("ERROR: The atom index should be A or B.")
    return ind
    end
end

function bits(tag::Int,i::Int, N1, N2)
    # Chenck the i-th element of the binary representation of tag
    SiteNum  = N1 * N2 * 2
    mask = 2^(SiteNum - i)
    n = tag & mask
    if n == mask
        return 1
    else
        return 0
    end
end
    
function StateConfig(tag, N1, N2)
    #=The configuration of the state with tag.
    Inputs: tag: tag of a state
            N1, N2: column and row numbers       
    Outputs: binary form of tag. type: 1D array=#
    
    dim = 2^(N1 * N2 * 2)
    if tag >= dim
        return println("Error: The tag is out of range.")
    else
        b = string(tag, base = 2, pad = N1 * N2 * 2)
        return b
    end
end

function flip(tag, i, j, N1, N2)
    #=Flip the spin on i,j site.
    Inputs: tag: tag of a state
            N1, N2: column and row numbers
            i,j: position of spins that are flipped
    Output: The tag of new state, type: int =#
    SiteNum = N1 * N2 * 2
    f = 2^(SiteNum - i) + 2^(SiteNum - j)
    return ntag = xor(tag,f)
end

function KitaevRhom(J, N1, N2)
    #=Kitaev Hamiltonian on N1 * N2 * 2 lattice
    Inputes: N1, N2: column and row numbers
             J: coupling constants
    Outpus: The Non-zero Hamiltonian element H[i] is in the 
            position (row[i], col[i])
            H, row, col : type: list =#
    SiteNum = N1 * N2 * 2
    dim = 2^SiteNum
    
    numNZero = 0  #count the number of non-zero element
    data = Float64[]
    row = Int[]
    col = Int[]
    for tag = 0: dim-1
        #println("The state numnber is: " , tag)
        temp = Dict{Int, Float64}() # A temporay dict
        
        for r = 0: N2-1
            for c = 0: N1-1
                ind = index(N1, N2, c, r, 'A')
                # Sx Sx
                next = index(N1, N2, c, r, 'B')
                
                ntag = flip(tag, ind, next, N1, N2)
                if ntag in keys(temp)
                    temp[ntag] += -J[1] /4
                else
                    temp[ntag] = -J[1] /4
                end  
                
                # Sy Sy
                next = index(N1, N2, c - 1, r, 'B')
                
                ntag = flip(tag, ind, next, N1, N2) 
                if ntag in keys(temp)
                    temp[ntag] += J[2] * (bits(tag,ind, N1, N2) - 0.5) * (bits(tag,next, N1, N2) - 0.5)
                else
                    temp[ntag] = J[2] * (bits(tag,ind, N1, N2) - 0.5) * (bits(tag,next, N1, N2) - 0.5)
                end
                        
                #Sz Sz
                next = index(N1, N2, c, r - 1, 'B')
                    
                if tag in keys(temp)
                    temp[tag] += - J[3] * (bits(tag,ind, N1, N2) - 0.5) * (bits(tag,next, N1, N2) - 0.5)
                else
                    temp[tag] = - J[3] * (bits(tag,ind, N1, N2) - 0.5)* (bits(tag,next, N1, N2) - 0.5)
                end
            end
        end
                        
        odTemp = sort(collect(keys(temp)))
        for sf in odTemp
            append!(col, [tag + 1])
            append!(row, [sf + 1])
            append!(data,[temp[sf]])
            numNZero += 1
        end
    end
    
    println("non zero elemens number =" , numNZero)
    println("Percentage =" , numNZero/(dim * dim) * 100,"%")
    return col, row, data
end

function makeH(col, row, data)
    H = sparse(row, col, data)
    return H
end
# Out:
# makeH (generic function with 1 method)

# %%
using SparseArrays
using Arpack

N1 = 3
N2 = 3
J = [1,1,1]

@time col, row, data = KitaevRhom(J, N1, N2)
@time H =  makeH(col, row, data)


@time e,x = eigs(H)
println(e/(N1*N2*2))
# Out:
# non zero elemens number =4980736
# Percentage =0.0072479248046875%
#   2.290302 seconds (17.68 M allocations: 1.961 GiB, 24.62% gc time)
#   0.218868 seconds (21 allocations: 158.001 MiB, 2.23% gc time)
#   8.474366 seconds (2.59 k allocations: 62.103 MiB, 0.29% gc time)
# [0.198493, -0.198493, -0.198493, 0.198493, -0.198493, 0.198493]

# %%
using SparseArrays
using Arpack

N1 = 3
N2 = 3
J = [1,1,1]

@time col, row, data = KitaevRhom(J, N1, N2)
@time H =  makeH(col, row, data)


@time e,x = eigs(H)
println(e/(N1*N2*2))
# Out:
# non zero elemens number =4980736
# Percentage =0.0072479248046875%
#   2.030082 seconds (17.67 M allocations: 1.960 GiB, 20.86% gc time)
#   0.250455 seconds (2.19 k allocations: 158.101 MiB, 1.86% gc time)
#   5.590781 seconds (1.76 k allocations: 62.072 MiB, 0.40% gc time)
# [0.198493, -0.198493, -0.198493, 0.198493, 0.195481, -0.195481]

# %% [markdown]
# \section{Kitaev model with translation symmetry}

# %%
function index(N1::Int, N2::Int, c::Int, r::Int, atom)
    #Calculate the index of the atoms in the (r,c) unit cell
    c = (c + N1) % N1 
    r = (r + N2) % N2 
    #println("(",r,",",c,")")
    n = r * N1 + c 
    if atom == 'A'
        ind = 2 * n + 1
    elseif atom == 'B'
        ind = 2 * n + 1 + 1
    else
        return println("ERROR: The atom index should be A or B.")
    return ind
    end
end

function bits(tag::Int,i::Int, N1, N2)
    # Chenck the i-th element of the binary representation of tag
    SiteNum  = N1 * N2 * 2
    mask = 2^(SiteNum - i)
    n = tag & mask
    if n == mask
        return 1
    else
        return 0
    end
end

function StateConfig(tag, N1, N2)
    #=The configuration of the state with tag.
    Inputs: tag: tag of a state
            N1, N2: column and row numbers       
    Outputs: binary form of tag. type: 1D array=#
    
    dim = 2^(N1 * N2 * 2)
    if tag >= dim
        return println("Error: The tag is out of range.")
    else
        b = string(tag, base = 2, pad = N1 * N2 * 2)
        return b
    end
end

function flip(tag, i, j, N1, N2)
    #=Flip the spin on i,j site.
    Inputs: tag: tag of a state
            N1, N2: column and row numbers
            i,j: position of spins that are flipped
    Output: The tag of new state, type: int =#
    SiteNum = N1 * N2 * 2
    f = 2^(SiteNum - i) + 2^(SiteNum - j)
    return ntag = xor(tag,f)
end

function cyclebits(n1::Int,n2::Int, tag::Int, N1::Int, N2::Int)
    #=Performs a cyclic permutations of n1 steps to the right and n2 steps upward.
       Inputs: tag: tag of the reference state
               n1: cycle times of n1-direction, columns,if n1=0, no cycle in columns
               n2: cycle times of n2-direction, rows,if n2=0, no cycle in rows
               N1: number of columns
               N2: number of rows
       Outputs: ntag: the tag of the outcoming state=#
    SiteNum = N1 * N2 * 2
    #config = StateConfig(tag, N1, N2)
    #cfig = [parse(Int,x) for x in config]
    cfig = [x for x = 1: SiteNum]

    a = reshape(cfig, 2, N1, N2)
    b = circshift(a, (0, n1, n2))
    ncfig = reshape(b, (SiteNum, 1))
    #println(ncfig)
    ntag = 0
    for i in 1:SiteNum
        ntag += 2^(SiteNum - i) * bits(tag, ncfig[i], N1, N2)
    end  
    return ntag
end

function MomBasis(k1::Int, k2::Int, N1::Int, N2::Int)
    #=Momentum basis list of a given k1, k2
       Inputs: k1: momentum in n1-direction
               k2: momentum in n2-direction
               N1: number of columns
               N2: number of rows
       Outpus: mbasis: momentum basis list
               Ra: list of corresponding cycle period 
                   R1: n1-direction 
                   R2: n2-direction=#
    SiteNum = N1 * N2 * 2
    dim = 2^SiteNum
    
    basis = ones(Int, dim)
    
    m1 = Dict{Int, Int}()
    m2 = Dict{Int, Int}()
    mb = Int[]
    
    #println("Finish initialize")
    # Translation symmetry along n1-direction
    for tag = 0: (dim-1)
        if basis[tag + 1] == 1
            for n1= 1:N1
                ntag = cyclebits(n1, 0, tag, N1, N2)
                if ntag > tag
                    basis[ntag + 1] = 0
                elseif ntag == tag
                    basis[ntag + 1] = 0
                    if k1%(N1/n1) == 0
                        m1[tag] = n1
                    end
                    break
                end
            end
        end
    end
 
    # Translation symmetry along n2-direction
    basis = ones(Int, dim)
    for tag = 0: (dim-1)
        if basis[tag + 1] == 1
            for n2= 1:N2
                ntag = cyclebits(0, n2, tag, N1, N2)
                if ntag > tag
                    basis[ntag + 1] = 0
                elseif ntag == tag
                    basis[ntag + 1] = 0
                    if k2%(N2/n2) == 0
                        m2[tag] = n2
                    end
                    break
                end
            end
        end
    end
   
    for x in collect(keys(m1))
        if x in collect(keys(m2))
            append!(mb,[x])
        end
    end
    return mb, m1, m2
end
# Out:
# MomBasis (generic function with 1 method)

# %%
N1 = 3
N2 = 3

k1 = 0
k2 = 0

@time mb, m1, m2 = MomBasis(k1, k2, N1, N2)
println("Finished!")
# Out:
# 110.652508 seconds (8.17 M allocations: 57.434 GiB, 6.28% gc time)
# Finished!

# %%
using Profile
@profile mb, m1, m2 = MomBasis(k1, k2, N1, N2)
println("Finished!")
# Out:
# Finished!

# %%
Profile.print()
# Out:
# 519 ./task.jl:259; (::getfield(IJulia, Symbol("##15#1...
#  519 ...yLI42/src/eventloop.jl:8; eventloop(::ZMQ.Socket)
#   519 ./essentials.jl:741; invokelatest
#    519 ./essentials.jl:742; #invokelatest#1
#     518 ...c/execute_request.jl:67; execute_request(::ZMQ.Socket, ::...
#      1   ...c/SoftGlobalScope.jl:209; softscope_include_string(::Modu...
#      1   ...c/SoftGlobalScope.jl:211; softscope_include_string(::Modu...
#       1 ./none:0; (::getfield(Base.Meta, Symbol("#k...
#        1 ./meta.jl:123; #parse#1(::Bool, ::Bool, ::Bool...
#         1 ./logging.jl:491; with_logger(::Function, ::Base....
#          1 ./logging.jl:395; with_logstate(::getfield(Base....
#           1 ./meta.jl:124; (::getfield(Base.Meta, Symbol(...
#            1 ./essentials.jl:355; cconvert(::Type, ::Int64)
#      3   ...c/SoftGlobalScope.jl:217; softscope_include_string(::Modu...
#       1 ...c/SoftGlobalScope.jl:194; add_linenum(::Expr, ::Int64, ::S...
#        1 ...c/SoftGlobalScope.jl:187; shift_linenum(::Expr, ::Int64, ...
#       2 ...c/SoftGlobalScope.jl:177; softscope(::Module, ::Expr)
#        1 ./none:0; #names
#         1 ./reflection.jl:98; #names#7
#        1 ...c/SoftGlobalScope.jl:124; _softscope
#         1 .../SoftGlobalScope.jl:144; _softscope(::Expr, ::Set{Symbol...
#          1 ./broadcast.jl:753; materialize(::Base.Broadcast.B...
#           1 ./broadcast.jl:770; copy(::Base.Broadcast.Broadcas...
#            1 ./broadcast.jl:627; combine_eltypes(::Function, :...
#             1 ...piler/typeinfer.jl:637; return_type(::Any, ::Any)
#      513 ...c/SoftGlobalScope.jl:218; softscope_include_string(::Modu...
#       513 ./boot.jl:328; eval
#        24  ./In[439]:106; MomBasis(::Int64, ::Int64, ::I...
#         1  ./In[439]:63; cyclebits(::Int64, ::Int64, ::I...
#         4  ./In[439]:64; cyclebits(::Int64, ::Int64, ::I...
#          4 ./In[439]:39; StateConfig
#           4 ./none:0; #string
#            4 ./intfuncs.jl:636; #string#321(::Int64, ::Int64,...
#             4 ./intfuncs.jl:546; bin(::UInt64, ::Int64, ::Bool)
#              4 ./iobuffer.jl:31; StringVector
#               4 ./strings/string.jl:60; _string_n
#         4  ./In[439]:65; cyclebits(::Int64, ::Int64, ::I...
#          3 ./array.jl:611; collect(::Base.Generator{Strin...
#           1 ./array.jl:597; _array_for
#            1 ./boot.jl:402; Type
#           2 ./array.jl:630; collect_to_with_first!
#            2 ./array.jl:651; collect_to!(::Array{Int64,1},...
#             2 ./generator.jl:47; iterate
#              2 ./none:0; #421
#               2 ./parse.jl:41; parse
#                1 ./parse.jl:41; #parse#346(::Int64, ::Funct...
#                1 ./parse.jl:43; #parse#346(::Int64, ::Funct...
#                 1 ./char.jl:221; -(::Char, ::Char)
#                  1 ./char.jl:50; Type
#                   1 ./char.jl:77; codepoint
#                    1 ./char.jl:127; Type
#                     1 ./char.jl:221; <
#          1 ./generator.jl:32; Base.Generator(::getfield(Main...
#           1 ./generator.jl:32; Type
#         3  ./In[439]:68; cyclebits(::Int64, ::Int64, ::I...
#          3 ./abstractarraymath.jl:184; circshift
#           3 ./multidimensional.jl:933; circshift!(::Array{Int64,3}, :...
#            1 ./multidimensional.jl:962; _circshift!
#            2 ./multidimensional.jl:963; _circshift!
#             1 ./multidimensional.jl:962; _circshift!(::Array{Int64,3}...
#              1 ...ltidimensional.jl:963; _circshift!
#               1 ...ltidimensional.jl:967; _circshift!
#                1 ...ltidimensional.jl:884; copyto!(::Array{Int64,3}, :...
#                 1 ...tidimensional.jl:896; macro expansion
#                  1 ./cartesian.jl:0; macro expansion
#         12 ./In[439]:73; cyclebits(::Int64, ::Int64, ::I...
#        1   ./In[439]:107; MomBasis(::Int64, ::Int64, ::I...
#        1   ./In[439]:112; MomBasis(::Int64, ::Int64, ::I...
#         1 ./array.jl:130; vect
#          1 ./abstractarray.jl:617; similar
#           1 ./abstractarray.jl:618; similar
#            1 ./boot.jl:419; Type
#             1 ./boot.jl:411; Type
#              1 ./boot.jl:402; Type
#        1   ./In[439]:123; MomBasis(::Int64, ::Int64, ::I...
#         1 ./array.jl:449; ones
#          1 ./array.jl:452; ones
#           1 ./boot.jl:411; Type
#            1 ./boot.jl:402; Type
#        19  ./In[439]:129; MomBasis(::Int64, ::Int64, ::I...
#         4 ./In[439]:65; cyclebits(::Int64, ::Int64, ::I...
#          2 ./array.jl:611; collect(::Base.Generator{Strin...
#           2 ./array.jl:597; _array_for
#            2 ./boot.jl:402; Type
#         3 ./In[439]:68; cyclebits(::Int64, ::Int64, ::I...
#          3 ./abstractarraymath.jl:184; circshift
#           1 ./abstractarray.jl:571; similar
#            1 ./boot.jl:406; similar
#           1 ./multidimensional.jl:932; circshift!(::Array{Int64,3}, :...
#            1 ./tuple.jl:283; ==
#             1 ./tuple.jl:287; _eq
#              1 ./range.jl:717; ==
#               1 ./promotion.jl:403; ==
#           1 ./multidimensional.jl:933; circshift!(::Array{Int64,3}, :...
#            1 ./multidimensional.jl:963; _circshift!
#             1 ./multidimensional.jl:962; _circshift!(::Array{Int64,3}...
#              1 ...ltidimensional.jl:960; _circshift!
#               1 ./range.jl:5; Colon
#                1 ./range.jl:274; Type
#                 1 ./range.jl:279; unitrange_last
#                  1 ./operators.jl:333; >=
#                   1 ./int.jl:428; <=
#         1 ./In[439]:69; cyclebits(::Int64, ::Int64, ::I...
#          1 ./reshapedarray.jl:51; reshape(::Array{Int64,3}, ::Tup...
#         9 ./In[439]:73; cyclebits(::Int64, ::Int64, ::I...
#         1 ./In[439]:75; cyclebits(::Int64, ::Int64, ::I...
#         1 ./reshapedarray.jl:51; cyclebits(::Int64, ::Int64, ::I...
#        5   ./In[439]:130; MomBasis(::Int64, ::Int64, ::I...
#         2 ./operators.jl:950; in(::Int64, ::Array{Int64,1})
#          2 ./promotion.jl:403; ==
#         2 ./operators.jl:953; in(::Int64, ::Array{Int64,1})
#         1 ./operators.jl:954; in(::Int64, ::Array{Int64,1})
#          1 ./array.jl:705; iterate
#        243 ./In[439]:131; MomBasis(::Int64, ::Int64, ::I...
#         2   ./array.jl:705; indexin(::Int64, ::Array{Int6...
#         1   ./array.jl:2193; indexin(::Int64, ::Array{Int6...
#          1 ./dict.jl:91; Dict{Int64,Int64}()
#           1 ./boot.jl:402; Type
#         2   ./array.jl:2194; indexin(::Int64, ::Array{Int6...
#          2 ./iterators.jl:332; iterate
#           2 ./iterators.jl:342; _zip_iterate_all
#            2 ./iterators.jl:350; _zip_iterate_some
#             2 ./array.jl:705; iterate
#              2 ./array.jl:705; iterate
#               2 ./array.jl:729; getindex
#         236 ./array.jl:2195; indexin(::Int64, ::Array{Int6...
#          233 ./dict.jl:421; get!
#           179 ./dict.jl:448; get!(::getfield(Base, Symbol...
#            5  ./dict.jl:305; ht_keyindex2!(::Dict{Int64,I...
#            7  ./dict.jl:308; ht_keyindex2!(::Dict{Int64,I...
#             7 ./sysimg.jl:18; getproperty
#            17 ./dict.jl:309; ht_keyindex2!(::Dict{Int64,I...
#             16 ./dict.jl:169; hashindex
#              16 ./hashing.jl:18; hash
#               16 ./float.jl:565; hash
#                4  ./float.jl:60; Type
#                12 ./float.jl:561; hx
#                 12 ./hashing.jl:62; hash_uint64
#                  2 ./hashing.jl:33; hash_64_64
#                   2 ./operators.jl:502; +
#                    2 ./int.jl:53; +
#                  2 ./hashing.jl:34; hash_64_64
#                   2 ./int.jl:321; xor
#                  4 ./hashing.jl:35; hash_64_64
#                   4 ./int.jl:53; +
#                  2 ./int.jl:321; hash_64_64
#                  1 ./int.jl:442; hash_64_64
#                  1 ./int.jl:443; hash_64_64
#             1  ./int.jl:53; hashindex
#            19 ./dict.jl:314; ht_keyindex2!(::Dict{Int64,I...
#             11 ./dict.jl:171; isslotempty
#              11 ./array.jl:729; getindex
#            2  ./dict.jl:315; ht_keyindex2!(::Dict{Int64,I...
#             2 ./int.jl:49; <
#            5  ./dict.jl:318; ht_keyindex2!(::Dict{Int64,I...
#            3  ./dict.jl:321; ht_keyindex2!(::Dict{Int64,I...
#             3 ./dict.jl:173; isslotmissing
#              3 ./sysimg.jl:18; ==
#            4  ./dict.jl:327; ht_keyindex2!(::Dict{Int64,I...
#            2  ./dict.jl:331; ht_keyindex2!(::Dict{Int64,I...
#             2 ./int.jl:53; +
#            3  ./dict.jl:333; ht_keyindex2!(::Dict{Int64,I...
#            86 ./dict.jl:349; ht_keyindex2!(::Dict{Int64,I...
#             2  ./dict.jl:0; rehash!(::Dict{Int64,Int64},...
#             5  ./dict.jl:192; rehash!(::Dict{Int64,Int64},...
#              5 ./array.jl:449; zeros
#               5 ./array.jl:452; zeros
#                5 ./boot.jl:411; Type
#                 5 ./boot.jl:402; Type
#             19 ./dict.jl:193; rehash!(::Dict{Int64,Int64},...
#              19 ./boot.jl:402; Type
#             24 ./dict.jl:194; rehash!(::Dict{Int64,Int64},...
#              24 ./boot.jl:402; Type
#             10 ./dict.jl:203; rehash!(::Dict{Int64,Int64},...
#              10 ./dict.jl:169; hashindex
#               10 ./hashing.jl:18; hash
#                10 ./float.jl:565; hash
#                 2 ./float.jl:60; Type
#                 8 ./float.jl:561; hx
#                  7 ./hashing.jl:62; hash_uint64
#                   3 ./hashing.jl:29; hash_64_64
#                    1 ./int.jl:53; +
#                    2 ./int.jl:274; ~
#                   1 ./hashing.jl:30; hash_64_64
#                    1 ./int.jl:321; xor
#                   3 ./int.jl:442; hash_64_64
#                  1 ./int.jl:53; +
#             6  ./dict.jl:204; rehash!(::Dict{Int64,Int64},...
#              2 ./operators.jl:185; !=
#               2 ./int.jl:432; ==
#                2 ./promotion.jl:350; ==
#                 2 ./promotion.jl:403; ==
#             1  ./dict.jl:205; rehash!(::Dict{Int64,Int64},...
#              1 ./int.jl:297; &
#             1  ./dict.jl:209; rehash!(::Dict{Int64,Int64},...
#              1 ./array.jl:767; setindex!
#             10 ./dict.jl:210; rehash!(::Dict{Int64,Int64},...
#              10 ./array.jl:767; setindex!
#             6  ./dict.jl:211; rehash!(::Dict{Int64,Int64},...
#              6 ./array.jl:767; setindex!
#             2  ./dict.jl:212; rehash!(::Dict{Int64,Int64},...
#              2 ./int.jl:53; +
#            3  ./int.jl:0; ht_keyindex2!(::Dict{Int64,I...
#           1   ./dict.jl:450; get!(::getfield(Base, Symbol...
#           45  ./dict.jl:462; get!(::getfield(Base, Symbol...
#            12 ./array.jl:767; _setindex!
#            6  ./dict.jl:357; _setindex!
#             5 ./array.jl:767; setindex!
#             1 ./sysimg.jl:18; getproperty
#            1  ./dict.jl:361; _setindex!
#             1 ./sysimg.jl:19; setproperty!
#            3  ./dict.jl:366; _setindex!
#             2 ./int.jl:54; *
#            21 ./dict.jl:368; _setindex!
#             2 ./dict.jl:192; rehash!(::Dict{Int64,Int64},...
#              2 ./array.jl:449; zeros
#               2 ./array.jl:452; zeros
#                2 ./boot.jl:411; Type
#                 2 ./boot.jl:402; Type
#             6 ./dict.jl:193; rehash!(::Dict{Int64,Int64},...
#              6 ./boot.jl:402; Type
#             9 ./dict.jl:194; rehash!(::Dict{Int64,Int64},...
#              9 ./boot.jl:402; Type
#             1 ./dict.jl:204; rehash!(::Dict{Int64,Int64},...
#              1 ./operators.jl:185; !=
#               1 ./int.jl:432; ==
#                1 ./promotion.jl:350; ==
#                 1 ./promotion.jl:403; ==
#             1 ./dict.jl:210; rehash!(::Dict{Int64,Int64},...
#              1 ./array.jl:767; setindex!
#             1 ./dict.jl:211; rehash!(::Dict{Int64,Int64},...
#              1 ./array.jl:767; setindex!
#             1 ./dict.jl:212; rehash!(::Dict{Int64,Int64},...
#              1 ./int.jl:53; +
#            1  ./int.jl:441; _setindex!
#            1  ./sysimg.jl:18; _setindex!
#           1   ./dict.jl:464; get!(::getfield(Base, Symbol...
#           1   ...ib/julia/sys.dylib:?; fill_bitarray_from_itr!(::Bi...
#          3   ./iterators.jl:333; iterate
#           3 ./iterators.jl:342; _zip_iterate_all
#            3 ./iterators.jl:350; _zip_iterate_some
#             3 ./array.jl:705; iterate
#              3 ./array.jl:199; length
#         1   ./array.jl:2197; indexin(::Int64, ::Array{Int6...
#          1 ./abstractarray.jl:618; similar
#           1 ./boot.jl:419; Type
#            1 ./boot.jl:414; Type
#         1   ./dict.jl:90; Dict{Int64,Int64}()
#        1   ./In[439]:138; MomBasis(::Int64, ::Int64, ::I...
#         1 ./array.jl:812; append!
#        8   ./In[509]:102; MomBasis(::Int64, ::Int64, ::I...
#         5 ./In[509]:68; cyclebits(::Int64, ::Int64, ::I...
#          5 ./abstractarraymath.jl:184; circshift
#           5 ./multidimensional.jl:933; circshift!(::Array{Int64,3}, :...
#            1 ./multidimensional.jl:962; _circshift!
#             1 ./multidimensional.jl:957; _circshift!(::Array{Int64,3}...
#              1 ./int.jl:221; mod
#               1 ./int.jl:0; fld
#            4 ./multidimensional.jl:963; _circshift!
#             1 ./multidimensional.jl:957; _circshift!(::Array{Int64,3}...
#              1 ./int.jl:220; mod
#               1 ./promotion.jl:403; ==
#             1 ./multidimensional.jl:963; _circshift!(::Array{Int64,3}...
#              1 ...ltidimensional.jl:963; _circshift!
#               1 ...ltidimensional.jl:967; _circshift!
#                1 ./cartesian.jl:65; copyto!(::Array{Int64,3}, :...
#         2 ./In[509]:69; cyclebits(::Int64, ::Int64, ::I...
#          1 ./reshapedarray.jl:51; reshape(::Array{Int64,3}, ::Tup...
#         1 ./reshapedarray.jl:51; cyclebits(::Int64, ::Int64, ::I...
#        10  ./In[509]:121; MomBasis(::Int64, ::Int64, ::I...
#         1 ./In[509]:64; cyclebits(::Int64, ::Int64, ::I...
#          1 ./In[509]:39; StateConfig
#           1 ./none:0; #string
#            1 ./intfuncs.jl:636; #string#321(::Int64, ::Int64,...
#             1 ./intfuncs.jl:546; bin(::UInt64, ::Int64, ::Bool)
#              1 ./strings/string.jl:71; StringVector
#         1 ./In[509]:65; cyclebits(::Int64, ::Int64, ::I...
#          1 ./array.jl:606; collect(::Base.Generator{Strin...
#           1 ./generator.jl:47; iterate
#            1 ./none:0; #439
#             1 ./parse.jl:41; parse
#              1 ./parse.jl:43; #parse#346(::Int64, ::Functi...
#               1 ./char.jl:221; -(::Char, ::Char)
#                1 ./int.jl:52; -
#         1 ./In[509]:68; cyclebits(::Int64, ::Int64, ::I...
#          1 ./abstractarraymath.jl:184; circshift
#           1 ./multidimensional.jl:933; circshift!(::Array{Int64,3}, :...
#            1 ./multidimensional.jl:963; _circshift!
#         6 ./In[509]:73; cyclebits(::Int64, ::Int64, ::I...
#        33  ./In[509]:136; MomBasis(::Int64, ::Int64, ::I...
#         3  ./abstractdict.jl:98; keys
#          3 ./abstractdict.jl:40; Type
#           3 ./abstractdict.jl:40; Type
#         28 ./array.jl:544; collect
#          28 ./array.jl:550; _collect
#           2  ./abstractarray.jl:0; copyto!(::Array{Int64,1}, ::B...
#           2  ./abstractarray.jl:668; copyto!(::Array{Int64,1}, ::B...
#            2 ./dict.jl:683; iterate
#             2 ./dict.jl:685; iterate
#              2 ./array.jl:729; getindex
#           2  ./abstractarray.jl:671; copyto!(::Array{Int64,1}, ::B...
#            2 ./array.jl:767; setindex!
#           19 ./abstractarray.jl:672; copyto!(::Array{Int64,1}, ::B...
#            11 ./dict.jl:683; iterate
#             11 ./dict.jl:661; skip_deleted
#              2 ./dict.jl:172; isslotfilled
#               2 ./promotion.jl:403; ==
#              2 ./int.jl:428; <=
#            1  ./dict.jl:684; iterate
#            1  ./int.jl:0; iterate
#            4  ./int.jl:49; iterate
#            2  ./promotion.jl:403; iterate
#           3  ./array.jl:517; _similar_for
#            3 ./abstractarray.jl:575; similar
#             3 ./abstractarray.jl:583; similar
#              3 ./boot.jl:411; Type
#               3 ./boot.jl:402; Type
#         2  ./operators.jl:950; in
#          2 ./promotion.jl:403; ==
#        1   ./In[509]:137; MomBasis(::Int64, ::Int64, ::I...
#         1 ./array.jl:130; vect
#          1 ./abstractarray.jl:617; similar
#           1 ./abstractarray.jl:618; similar
#            1 ./boot.jl:419; Type
#             1 ./boot.jl:411; Type
#              1 ./boot.jl:402; Type
#        7   ./In[523]:102; MomBasis(::Int64, ::Int64, ::I...
#         1 ./In[523]:68; cyclebits(::Int64, ::Int64, ::I...
#          1 ./abstractarraymath.jl:184; circshift
#           1 ./multidimensional.jl:933; circshift!(::Array{Int64,3}, :...
#            1 ./multidimensional.jl:963; _circshift!
#             1 ./multidimensional.jl:963; _circshift!(::Array{Int64,3}...
#              1 ...ltidimensional.jl:957; _circshift!
#               1 ./int.jl:221; mod
#                1 ./int.jl:0; fld
#         2 ./In[523]:69; cyclebits(::Int64, ::Int64, ::I...
#          2 ./reshapedarray.jl:51; reshape(::Array{Int64,3}, ::Tup...
#         3 ./In[523]:73; cyclebits(::Int64, ::Int64, ::I...
#          1 ./intfuncs.jl:220; ^
#           1 ./intfuncs.jl:0; power_by_squaring(::Int64, ::In...
#         1 ./reshapedarray.jl:51; cyclebits(::Int64, ::Int64, ::I...
#        6   ./In[523]:121; MomBasis(::Int64, ::Int64, ::I...
#         1 ./In[523]:65; cyclebits(::Int64, ::Int64, ::I...
#         2 ./In[523]:68; cyclebits(::Int64, ::Int64, ::I...
#          2 ./abstractarraymath.jl:184; circshift
#           2 ./multidimensional.jl:933; circshift!(::Array{Int64,3}, :...
#            2 ./multidimensional.jl:962; _circshift!
#             1 ./multidimensional.jl:957; _circshift!(::Array{Int64,3}...
#              1 ./int.jl:54; mod
#         2 ./In[523]:73; cyclebits(::Int64, ::Int64, ::I...
#         1 ./reshapedarray.jl:51; cyclebits(::Int64, ::Int64, ::I...
#        31  ./In[523]:136; MomBasis(::Int64, ::Int64, ::I...
#         4  ./abstractdict.jl:98; keys
#          4 ./abstractdict.jl:40; Type
#           4 ./abstractdict.jl:40; Type
#         25 ./array.jl:544; collect
#          25 ./array.jl:550; _collect
#           1  ./abstractarray.jl:0; copyto!(::Array{Int64,1}, ::B...
#           1  ./abstractarray.jl:668; copyto!(::Array{Int64,1}, ::B...
#            1 ./dict.jl:683; iterate
#             1 ./dict.jl:685; iterate
#              1 ./array.jl:729; getindex
#           23 ./abstractarray.jl:672; copyto!(::Array{Int64,1}, ::B...
#            17 ./dict.jl:683; iterate
#             17 ./dict.jl:661; skip_deleted
#              3 ./dict.jl:172; isslotfilled
#               3 ./promotion.jl:403; ==
#              7 ./int.jl:428; <=
#            1  ./int.jl:0; iterate
#            5  ./int.jl:49; iterate
#         1  ./operators.jl:950; in
#          1 ./promotion.jl:403; ==
#         1  ./operators.jl:954; in
#          1 ./array.jl:705; iterate
#        8   ./In[537]:103; MomBasis(::Int64, ::Int64, ::I...
#         1 ./In[537]:68; cyclebits(::Int64, ::Int64, ::I...
#          1 ./reshapedarray.jl:115; reshape
#           1 ./reshapedarray.jl:51; reshape
#         5 ./In[537]:69; cyclebits(::Int64, ::Int64, ::I...
#          5 ./abstractarraymath.jl:184; circshift
#           1 ./abstractarray.jl:571; similar
#            1 ./abstractarray.jl:572; similar
#             1 ./array.jl:317; similar
#              1 ./boot.jl:413; Type
#               1 ./boot.jl:406; Type
#           4 ./multidimensional.jl:933; circshift!(::Array{Int64,3}, :...
#            4 ./multidimensional.jl:963; _circshift!
#             1 ./multidimensional.jl:962; _circshift!(::Array{Int64,3}...
#              1 ...ltidimensional.jl:960; _circshift!
#               1 ./range.jl:5; Colon
#                1 ./range.jl:274; Type
#                 1 ./range.jl:279; unitrange_last
#                  1 ./operators.jl:333; >=
#                   1 ./int.jl:428; <=
#         1 ./In[537]:70; cyclebits(::Int64, ::Int64, ::I...
#          1 ./reshapedarray.jl:51; reshape(::Array{Int64,3}, ::Tup...
#         1 ./In[537]:74; cyclebits(::Int64, ::Int64, ::I...
#          1 ./intfuncs.jl:220; ^
#           1 ./intfuncs.jl:206; power_by_squaring(::Int64, ::I...
#            1 ./int.jl:448; >>
#             1 ./int.jl:0; >>
#        1   ./In[537]:109; MomBasis(::Int64, ::Int64, ::I...
#         1 ./dict.jl:387; setindex!(::Dict{Int64,Int64}, ...
#        12  ./In[537]:122; MomBasis(::Int64, ::Int64, ::I...
#         1 ./In[537]:68; cyclebits(::Int64, ::Int64, ::I...
#          1 ./reshapedarray.jl:115; reshape
#           1 ./reshapedarray.jl:51; reshape
#         7 ./In[537]:69; cyclebits(::Int64, ::Int64, ::I...
#          7 ./abstractarraymath.jl:184; circshift
#           7 ./multidimensional.jl:933; circshift!(::Array{Int64,3}, :...
#            1 ./multidimensional.jl:962; _circshift!
#             1 ./multidimensional.jl:962; _circshift!(::Array{Int64,3}...
#              1 ...ltidimensional.jl:963; _circshift!
#               1 ...ltidimensional.jl:967; _circshift!
#                1 ...ltidimensional.jl:240; Type
#                 1 ...tidimensional.jl:240; Type
#            6 ./multidimensional.jl:963; _circshift!
#             1 ./multidimensional.jl:962; _circshift!(::Array{Int64,3}...
#              1 ...ltidimensional.jl:957; _circshift!
#               1 ./int.jl:221; mod
#                1 ./int.jl:241; fld
#                 1 ./int.jl:232; div
#             1 ./multidimensional.jl:963; _circshift!(::Array{Int64,3}...
#              1 ...ltidimensional.jl:962; _circshift!
#               1 ...ltidimensional.jl:967; _circshift!
#                1 ...ltidimensional.jl:884; copyto!(::Array{Int64,3}, :...
#                 1 ...tidimensional.jl:884; macro expansion
#                  1 ./abstractarray.jl:863; isempty
#                   1 ...idimensional.jl:359; length
#                    1 ...idimensional.jl:356; size
#                     1 ./tuple.jl:188; map
#                      1 ./tuple.jl:185; map
#                       1 ./int.jl:53; dimlength
#         3 ./In[537]:74; cyclebits(::Int64, ::Int64, ::I...
#          1 ./intfuncs.jl:220; ^
#           1 ./intfuncs.jl:201; power_by_squaring(::Int64, ::I...
#            1 ./int.jl:54; *
#        1   ./In[537]:128; MomBasis(::Int64, ::Int64, ::I...
#         1 ./dict.jl:382; setindex!(::Dict{Int64,Int64}, ...
#          1 ./dict.jl:349; ht_keyindex2!(::Dict{Int64,Int...
#           1 ./dict.jl:194; rehash!(::Dict{Int64,Int64}, :...
#            1 ./boot.jl:402; Type
#        1   ./In[537]:136; MomBasis(::Int64, ::Int64, ::I...
#         1 ./array.jl:705; iterate
#          1 ./array.jl:705; iterate
#           1 ./array.jl:729; getindex
#        89  ./In[537]:137; MomBasis(::Int64, ::Int64, ::I...
#         8  ./abstractdict.jl:98; keys
#          8 ./abstractdict.jl:40; Type
#           8 ./abstractdict.jl:40; Type
#         80 ./array.jl:544; collect
#          80 ./array.jl:550; _collect
#           2  ./abstractarray.jl:0; copyto!(::Array{Int64,1}, ::B...
#           8  ./abstractarray.jl:668; copyto!(::Array{Int64,1}, ::B...
#            8 ./dict.jl:683; iterate
#             8 ./dict.jl:685; iterate
#              8 ./array.jl:729; getindex
#           3  ./abstractarray.jl:671; copyto!(::Array{Int64,1}, ::B...
#            1 ./array.jl:729; setindex!
#            2 ./array.jl:767; setindex!
#           60 ./abstractarray.jl:672; copyto!(::Array{Int64,1}, ::B...
#            39 ./dict.jl:683; iterate
#             39 ./dict.jl:661; skip_deleted
#              18 ./dict.jl:172; isslotfilled
#               18 ./promotion.jl:403; ==
#              7  ./int.jl:428; <=
#            3  ./dict.jl:684; iterate
#            5  ./int.jl:0; iterate
#            11 ./int.jl:49; iterate
#            2  ./promotion.jl:403; iterate
#           1  ./abstractarray.jl:674; copyto!(::Array{Int64,1}, ::B...
#           6  ./boot.jl:402; _similar_for
#         1  ./operators.jl:954; in
#          1 ./array.jl:705; iterate
#        1   ./array.jl:896; MomBasis(::Int64, ::Int64, ::I...
#         1 ./array.jl:269; copyto!(::Array{Int64,1}, ::Int...
#        1   ./operators.jl:0; MomBasis(::Int64, ::Int64, ::I...
#        1   ./operators.jl:953; MomBasis(::Int64, ::Int64, ::I...
#     1   ...c/execute_request.jl:112; execute_request(::ZMQ.Socket, ::...
#      1 ./essentials.jl:741; invokelatest
#       1 ./essentials.jl:742; #invokelatest#1
#        1 ...yLI42/src/display.jl:95; display_dict(::Tuple{Array{Int64...
#         1 ...yLI42/src/display.jl:3; _showable(::Array{MIME,1}, ::Tup...
#          1 ./reducedim.jl:658; any
#           1 ./reducedim.jl:658; #any#559
#            1 ./reduce.jl:616; _any(::getfield(IJulia, Symbo...
#             1 ./reflection.jl:1102; (::getfield(IJulia, Symbol("...

# %%
m1 = Dict{Int, Int}()
m2 = Dict{Int, Int}()
m1[2] = 5
m1[1] = 6
println(m1)
m2[2] = 5
m2[7] = 8
println(m2)
# Out:
# Dict(2=>5,1=>6)
# Dict(7=>8,2=>5)

# %%
N1 = 3
N2 = 2

k1 = 0
k2 = 0

@time mb, r1, r2 = MomBasis(k1, k2, N1, N2)
println("Finished!")
# Out:
#   0.195224 seconds (243.32 k allocations: 132.265 MiB, 52.48% gc time)
# Finished!

# %%
for x in collect(keys(m1))
    if x in collect(keys(m2))
        println(x)
    end
end
# Out:
# 2

# %%
N1 = 2
N2 = 3
tag = 167
n1 = 2
n2 = 3
ntag = cyclebits(n1,n2, tag, N1, N2)
print(ntag)
# Out:
# 167

# %%
println(m2)
# Out:
# Dict(7=>8,2=>5)
